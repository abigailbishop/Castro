# %%
import yt
import glob
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt
plt.ion()

# %%
yt.funcs.mylog.setLevel(0)

plotfiles = sorted(list(glob.glob("det_x_plt?????")))

# %%
def get_x_var(pf, var="Temp"):
    ds = yt.load(pf)
    time = float(ds.current_time)
    ad = ds.all_data()
    srt = np.argsort(ad['x'])                                                                                                                                                
    x_coord = np.array(ad['x'][srt])                                                                                                                                         
    var = np.array(ad[var][srt])
    return time, x_coord, var

# %%
for n, pf in enumerate(plotfiles):
    t, x, v = get_x_var(pf)
    if n == 0:
        fig = plt.figure()
        ax = fig.add_subplot(111)
        ax.set_ylim((1.e7, 5.e9))
        ax.set_title(t)
        line, = ax.semilogy(x, v)
    else:
        line.set_data(x, v)
        ax.set_title(t)
        fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e12fe32aab1c> in <module>()
#       1 for n, pf in enumerate(plotfiles):
# ----> 2     t, x, v = get_x_var(pf)
#       3     if n == 0:
#       4         fig = plt.figure()
#       5         ax = fig.add_subplot(111)
#
# <ipython-input-3-f97248dbbd66> in get_x_var(pf, var)
#       3     time = float(ds.current_time)
#       4     ad = ds.all_data()
# ----> 5     srt = np.argsort(ad['x'])
#       6     x_coord = np.array(ad['x'][srt])
#       7     var = np.array(ad[var][srt])
#
# ~/.local/lib/python3.6/site-packages/yt/data_objects/data_containers.py in __getitem__(self, key)
#     273         Returns a single field.  Will add if necessary.
#     274         """
# --> 275         f = self._determine_fields([key])[0]
#     276         if f not in self.field_data and key not in self.field_data:
#     277             if f in self._container_fields:
#
# ~/.local/lib/python3.6/site-packages/yt/data_objects/data_containers.py in _determine_fields(self, fields)
#    1126             else:
#    1127                 fname = field
# -> 1128                 finfo = self.ds._get_field_info("unknown", fname)
#    1129                 if finfo.particle_type:
#    1130                     ftype = self._current_particle_type
#
# ~/.local/lib/python3.6/site-packages/yt/data_objects/static_output.py in _get_field_info(self, ftype, fname)
#     709     _last_finfo = None
#     710     def _get_field_info(self, ftype, fname = None):
# --> 711         self.index
#     712         if fname is None:
#     713             if isinstance(ftype, DerivedField):
#
# ~/.local/lib/python3.6/site-packages/yt/data_objects/static_output.py in index(self)
#     507             oldsettings = np.geterr()
#     508             np.seterr(all='ignore')
# --> 509             self.create_field_info()
#     510             np.seterr(**oldsettings)
#     511         return self._instantiated_index
#
# ~/.local/lib/python3.6/site-packages/yt/data_objects/static_output.py in create_field_info(self)
#     565         mylog.debug("Loading field plugins.")
#     566         self.field_info.load_all_plugins()
# --> 567         deps, unloaded = self.field_info.check_derived_fields()
#     568         self.field_dependencies.update(deps)
#     569         self.fields = FieldTypeContainer(self)
#
# ~/.local/lib/python3.6/site-packages/yt/fields/field_info_container.py in check_derived_fields(self, fields_to_check)
#     364             fi = self[field]
#     365             try:
# --> 366                 fd = fi.get_dependencies(ds = self.ds)
#     367             except Exception as e:
#     368                 if field in self._show_field_errors:
#
# ~/.local/lib/python3.6/site-packages/yt/fields/derived_field.py in get_dependencies(self, *args, **kwargs)
#     205         This returns a list of names of fields that this field depends on.
#     206         """
# --> 207         e = FieldDetector(*args, **kwargs)
#     208         if self._function.__name__ == '<lambda>':
#     209             e.requested.append(self.name)
#
# ~/.local/lib/python3.6/site-packages/yt/fields/field_detector.py in __init__(self, nd, ds, flat, field_parameters)
#      56         self.ds = ds
#      57
# ---> 58         class fake_index(object):
#      59             class fake_io(object):
#      60                 def _read_data_set(io_self, data, field):
#
# KeyboardInterrupt:
